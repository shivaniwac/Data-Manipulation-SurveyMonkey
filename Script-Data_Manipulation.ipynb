# %%
import pandas as pd
import os

# %%
pwd = os.getcwd()

# %%
DS =pd.read_excel("Data - Survey Monkey Output Edited.xlsx", sheet_name="Edited_Data")

# %%
DS
# Out:
#      Respondent ID          Start Date            End Date  Email Address  \
# 0       5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1       2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2       4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3       5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4       3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ..             ...                 ...                 ...            ...
# 193     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 194     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 195     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 196     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 197     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# ...

# %%
DS.head()
# Out:
#    Respondent ID          Start Date            End Date  Email Address  \
# 0     5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1     2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2     4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3     5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4     3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
#
#    First Name  Last Name  Custom Data 1  \
# 0         NaN        NaN            NaN
# 1         NaN        NaN            NaN
# 2         NaN        NaN            NaN
# 3         NaN        NaN            NaN
# 4         NaN        NaN            NaN
#
#   Identify which division you work in.-Response  \
# 0                                Infrastructure
# 1                                       Finance
# 2                                Infrastructure
# 3                                Infrastructure
# ...

# %%
DS_modified = DS.copy()
DS_modified
# Out:
#      Respondent ID          Start Date            End Date  Email Address  \
# 0       5379192392 2021-01-22 12:01:17 2021-01-22 12:40:34            NaN
# 1       2658722536 2021-01-22 06:56:37 2021-01-22 07:34:10            NaN
# 2       4044163394 2021-01-22 06:35:18 2021-01-22 06:47:32            NaN
# 3       5535865599 2021-01-21 21:29:32 2021-01-21 21:40:24            NaN
# 4       3356802928 2021-01-21 17:26:39 2021-01-21 17:44:40            NaN
# ..             ...                 ...                 ...            ...
# 193     7940065082 2021-01-11 06:19:18 2021-01-11 06:32:59            NaN
# 194     5157705612 2021-01-11 06:19:14 2021-01-11 06:33:29            NaN
# 195     9920755555 2021-01-11 06:18:48 2021-01-11 06:27:27            NaN
# 196     6638341389 2021-01-11 06:19:01 2021-01-11 06:33:06            NaN
# 197     8114622230 2021-01-11 06:18:50 2021-01-11 06:26:46            NaN
#
#      First Name  Last Name  Custom Data 1  \
# ...

# %%
DS_modified.columns
# Out:
# Index(['Respondent ID', 'Start Date', 'End Date', 'Email Address',
#        'First Name', 'Last Name', 'Custom Data 1',
#        'Identify which division you work in.-Response',
#        'Identify which division you work in.-Other (please specify)',
#        'Which of the following best describes your position level?-Response',
#        ...
#        'Question 29-Response 9', 'Question 29-Response 10',
#        'Question 29-Response 11', 'Question 29-Response 12',
#        'Question 29-Response 13', 'Question 29-Response 14',
#        'Question 30-Response 1', 'Question 30-Response 2',
#        'Question 30-Response 3', 'Question 30-Response 3.1'],
#       dtype='object', length=101)

# %%
columns_to_drop = ['Start Date', 'End Date', 'Email Address',
       'First Name', 'Last Name', 'Custom Data 1']
columns_to_drop
# Out:
# ['Start Date',
#  'End Date',
#  'Email Address',
#  'First Name',
#  'Last Name',
#  'Custom Data 1']

# %%
DS_modified = DS_modified.drop(columns = columns_to_drop)

# %%
DS_modified
# Out:
#      Respondent ID Identify which division you work in.-Response  \
# 0       5379192392                                Infrastructure
# 1       2658722536                                       Finance
# 2       4044163394                                Infrastructure
# 3       5535865599                                Infrastructure
# 4       3356802928                               Port Operations
# ..             ...                                           ...
# 193     7940065082                                Infrastructure
# 194     5157705612                                       Finance
# 195     9920755555                               Port Operations
# 196     6638341389                                Infrastructure
# 197     8114622230                        Information Technology
#
#     Identify which division you work in.-Other (please specify)  \
# 0                                                  NaN
# 1                                                  NaN
# ...

# %%
id_vars= DS_modified.columns[:8]
value_vars =  DS_modified.columns[8:]
#value_vars

# %%
DS_MELTED = DS_modified.melt(id_vars=id_vars, value_vars=value_vars)
DS_MELTED
# Out:
#        Respondent ID Identify which division you work in.-Response  \
# 0         5379192392                                Infrastructure
# 1         2658722536                                       Finance
# 2         4044163394                                Infrastructure
# 3         5535865599                                Infrastructure
# 4         3356802928                               Port Operations
# ...              ...                                           ...
# 17221     7940065082                                Infrastructure
# 17222     5157705612                                       Finance
# 17223     9920755555                               Port Operations
# 17224     6638341389                                Infrastructure
# 17225     8114622230                        Information Technology
#
#       Identify which division you work in.-Other (please specify)  \
# 0                                                    NaN
# ...

# %%
 DS_MELTED = DS_modified.melt(id_vars=id_vars, value_vars=value_vars,var_name="Question&subquestion", value_name="Answer")

# %%
 DS_MELTED
# Out:
#        Respondent ID Identify which division you work in.-Response  \
# 0         5379192392                                Infrastructure
# 1         2658722536                                       Finance
# 2         4044163394                                Infrastructure
# 3         5535865599                                Infrastructure
# 4         3356802928                               Port Operations
# ...              ...                                           ...
# 17221     7940065082                                Infrastructure
# 17222     5157705612                                       Finance
# 17223     9920755555                               Port Operations
# 17224     6638341389                                Infrastructure
# 17225     8114622230                        Information Technology
#
#       Identify which division you work in.-Other (please specify)  \
# 0                                                    NaN
# ...

# %%
Question =pd.read_excel("Data - Survey Monkey Output Edited.xlsx", sheet_name="Question")

# %%
Question
# Out:
#       RawQuestion RawSubQuestion       Question  SubQuestion  \
# 0   Respondent ID            NaN  Respondent ID          NaN
# 1      Start Date            NaN     Start Date          NaN
# 2        End Date            NaN       End Date          NaN
# 3   Email Address            NaN  Email Address          NaN
# 4      First Name            NaN     First Name          NaN
# ..            ...            ...            ...          ...
# 95            NaN    Response 13    Question 29  Response 13
# 96            NaN    Response 14    Question 29  Response 14
# 97    Question 30     Response 1    Question 30   Response 1
# 98            NaN     Response 2    Question 30   Response 2
# 99            NaN     Response 3    Question 30   Response 3
#
#        Question&subquestion
# 0             Respondent ID
# 1                Start Date
# 2                  End Date
# 3             Email Address
# 4                First Name
# ..                      ...
# ...

# %%
columns_to_dropp = ["RawQuestion","RawSubQuestion","SubQuestion"]
columns_to_dropp
# Out:
# ['RawQuestion', 'RawSubQuestion', 'SubQuestion']

# %%
Question= Question.drop(columns = columns_to_dropp)

# %%
Question
# Out:
#          Question     Question&subquestion
# 0   Respondent ID            Respondent ID
# 1      Start Date               Start Date
# 2        End Date                 End Date
# 3   Email Address            Email Address
# 4      First Name               First Name
# ..            ...                      ...
# 95    Question 29  Question 29-Response 13
# 96    Question 29  Question 29-Response 14
# 97    Question 30   Question 30-Response 1
# 98    Question 30   Question 30-Response 2
# 99    Question 30   Question 30-Response 3
#
# [100 rows x 2 columns]

# %%
Question.dropna
# Out:
# <bound method DataFrame.dropna of          Question     Question&subquestion
# 0   Respondent ID            Respondent ID
# 1      Start Date               Start Date
# 2        End Date                 End Date
# 3   Email Address            Email Address
# 4      First Name               First Name
# ..            ...                      ...
# 95    Question 29  Question 29-Response 13
# 96    Question 29  Question 29-Response 14
# 97    Question 30   Question 30-Response 1
# 98    Question 30   Question 30-Response 2
# 99    Question 30   Question 30-Response 3
#
# [100 rows x 2 columns]>

# %%
DS_merge = pd.merge(left= DS_MELTED ,right=Question , how="left", left_on="Question&subquestion", right_on="Question&subquestion")

# %%
DS_merge
# Out:
#        Respondent ID Identify which division you work in.-Response  \
# 0         5379192392                                Infrastructure
# 1         2658722536                                       Finance
# 2         4044163394                                Infrastructure
# 3         5535865599                                Infrastructure
# 4         3356802928                               Port Operations
# ...              ...                                           ...
# 17221     7940065082                                Infrastructure
# 17222     5157705612                                       Finance
# 17223     9920755555                               Port Operations
# 17224     6638341389                                Infrastructure
# 17225     8114622230                        Information Technology
#
#       Identify which division you work in.-Other (please specify)  \
# 0                                                    NaN
# ...

# %%
print("Original Data",len(DS_MELTED))
print("Merged_data", len(DS_merge ))
DS_merge
# Out:
# Original Data 17226
# Merged_data 17226
#        Respondent ID Identify which division you work in.-Response  \
# 0         5379192392                                Infrastructure
# 1         2658722536                                       Finance
# 2         4044163394                                Infrastructure
# 3         5535865599                                Infrastructure
# 4         3356802928                               Port Operations
# ...              ...                                           ...
# 17221     7940065082                                Infrastructure
# 17222     5157705612                                       Finance
# 17223     9920755555                               Port Operations
# 17224     6638341389                                Infrastructure
# 17225     8114622230                        Information Technology
#
#       Identify which division you work in.-Other (please specify)  \
# ...

# %%
Number_of_response = DS_merge[DS_merge["Answer"].notna()]
Number_of_response =Number_of_response.groupby("Question")["Respondent ID"].nunique().reset_index()

# %%
Number_of_response
# Out:
#        Question  Respondent ID
# 0    Question 1            119
# 1   Question 10            198
# 2   Question 11            164
# 3   Question 12            114
# 4   Question 13            108
# 5   Question 14            105
# 6   Question 15            114
# 7   Question 16            117
# 8   Question 17            135
# 9   Question 18            109
# 10  Question 19            157
# 11   Question 2            118
# 12  Question 20            105
# 13  Question 21            127
# 14  Question 22            160
# 15  Question 23            120
# 16  Question 24            195
# 17  Question 25            198
# 18  Question 26            193
# 19  Question 27            153
# 20  Question 28            119
# 21  Question 29            198
# 22   Question 3            117
# 23  Question 30            182
# 24   Question 4            161
# 25   Question 5            194
# 26   Question 6            196
# 27   Question 7            162
# 28   Question 8            190
# ...

# %%
Number_of_response.rename(columns={"Respondent ID":"Respondents"},inplace=True)

# %%
Number_of_response
# Out:
#        Question  Respondents
# 0    Question 1          119
# 1   Question 10          198
# 2   Question 11          164
# 3   Question 12          114
# 4   Question 13          108
# 5   Question 14          105
# 6   Question 15          114
# 7   Question 16          117
# 8   Question 17          135
# 9   Question 18          109
# 10  Question 19          157
# 11   Question 2          118
# 12  Question 20          105
# 13  Question 21          127
# 14  Question 22          160
# 15  Question 23          120
# 16  Question 24          195
# 17  Question 25          198
# 18  Question 26          193
# 19  Question 27          153
# 20  Question 28          119
# 21  Question 29          198
# 22   Question 3          117
# 23  Question 30          182
# 24   Question 4          161
# 25   Question 5          194
# 26   Question 6          196
# 27   Question 7          162
# 28   Question 8          190
# 29   Question 9          188

# %%
DS_merge_two = pd.merge(left= DS_merge ,right=Number_of_response
, how="left", left_on="Question", right_on="Question")
print("Original Data",len(DS_merge))
print("Merged_data", len(DS_merge_two))
DS_merge_two
# Out:
# Original Data 17226
# Merged_data 17226
#        Respondent ID Identify which division you work in.-Response  \
# 0         5379192392                                Infrastructure
# 1         2658722536                                       Finance
# 2         4044163394                                Infrastructure
# 3         5535865599                                Infrastructure
# 4         3356802928                               Port Operations
# ...              ...                                           ...
# 17221     7940065082                                Infrastructure
# 17222     5157705612                                       Finance
# 17223     9920755555                               Port Operations
# 17224     6638341389                                Infrastructure
# 17225     8114622230                        Information Technology
#
#       Identify which division you work in.-Other (please specify)  \
# ...

# %%
Same_Answer = Same_Answer[Same_Answer["Answer"].notna()]
Same_Answer = Same_Answer.groupby(["Question&subquestion", "Answer"])["Respondent ID"].nunique().reset_index()
Same_Answer.rename(columns={"Respondent ID": "Same_Answer"}, inplace=True)
print(Same_Answer)
# Out:
#       Question&subquestion    Answer  Same_Answer
# 0      Question 1-Response  Answer 1           14
# 1      Question 1-Response  Answer 2           10
# 2      Question 1-Response  Answer 3           13
# 3      Question 1-Response  Answer 4           17
# 4      Question 1-Response  Answer 5           22
# ..                     ...       ...          ...
# 683  Question 9-Response 4  Answer 4           16
# 684  Question 9-Response 4  Answer 5           13
# 685  Question 9-Response 4  Answer 6           14
# 686  Question 9-Response 4  Answer 7           12
# 687  Question 9-Response 4  Answer 8           19
#
# [688 rows x 3 columns]

# %%
DS_merge_three = pd.merge(left= DS_merge_two ,right=Same_Answer
, how="left", left_on=["Question&subquestion", "Answer"], right_on=["Question&subquestion", "Answer"])
DS_merge_three["Same_Answer"].fillna(0, inplace = True)
print("Original Data",len(DS_merge_two))
print("Merged_data", len(DS_merge_two))
DS_merge_three
# Out:
# Original Data 17226
# Merged_data 17226
#        Respondent ID Identify which division you work in.-Response  \
# 0         5379192392                                Infrastructure
# 1         2658722536                                       Finance
# 2         4044163394                                Infrastructure
# 3         5535865599                                Infrastructure
# 4         3356802928                               Port Operations
# ...              ...                                           ...
# 17221     7940065082                                Infrastructure
# 17222     5157705612                                       Finance
# 17223     9920755555                               Port Operations
# 17224     6638341389                                Infrastructure
# 17225     8114622230                        Information Technology
#
#       Identify which division you work in.-Other (please specify)  \
# ...

# %%
DS_merge_three.columns
# Out:
# Index(['Respondent ID', 'Identify which division you work in.-Response',
#        'Identify which division you work in.-Other (please specify)',
#        'Which of the following best describes your position level?-Response',
#        'Which generation are you apart of?-Response',
#        'Please select the gender in which you identify.-Response',
#        'Which duration range best aligns with your tenure at your company?-Response',
#        'Which of the following best describes your employment type?-Response',
#        'Question&subquestion', 'Answer', 'Question', 'Respondents',
#        'Same_Answer'],
#       dtype='object')

# %%
('Identify which division you work in.-Response','Identify which division you work in.-Other (please specify)',
       'Which of the following best describes your position level?-Response',
       'Which generation are you apart of?-Response',
       'Please select the gender in which you identify.-Response',
       'Which duration range best aligns with your tenure at your company?-Response',
       'Which of the following best describes your employment type?-Response')
# Out:
#   Cell In[153], line 6
#     'Which of the following best describes your employment type?-Response')
#                                                                           ^
# SyntaxError: unmatched ')'

# %%
output = DS_merge_three

output.rename(columns={
    'Identify which division you work in.-Response': "Division Primary",
    'Identify which division you work in.-Other (please specify)': "Division Secondary",
    'Which of the following best describes your position level?-Response': "Position Level",
    'Which generation are you apart of?-Response': "Generation",
    'Please select the gender in which you identify.-Response': "Gender",
    'Which duration range best aligns with your tenure at your company?-Response': "Tenure",
    'Which of the following best describes your employment type?-Response': "Employment Type"
}, inplace=True)

print(output)
# Out:
#        Respondent ID        Division Primary Division Secondary  \
# 0         5379192392          Infrastructure                NaN
# 1         2658722536                 Finance                NaN
# 2         4044163394          Infrastructure                NaN
# 3         5535865599          Infrastructure                NaN
# 4         3356802928         Port Operations                NaN
# ...              ...                     ...                ...
# 17221     7940065082          Infrastructure                NaN
# 17222     5157705612                 Finance                NaN
# 17223     9920755555         Port Operations                NaN
# 17224     6638341389          Infrastructure                NaN
# 17225     8114622230  Information Technology                NaN
#
#         Position Level                             Generation      Gender  \
# 0                Staff  Generation X (born between 1965-1980)        Male
# ...

# %%
output
# Out:
#        Respondent ID        Division Primary Division Secondary  \
# 0         5379192392          Infrastructure                NaN
# 1         2658722536                 Finance                NaN
# 2         4044163394          Infrastructure                NaN
# 3         5535865599          Infrastructure                NaN
# 4         3356802928         Port Operations                NaN
# ...              ...                     ...                ...
# 17221     7940065082          Infrastructure                NaN
# 17222     5157705612                 Finance                NaN
# 17223     9920755555         Port Operations                NaN
# 17224     6638341389          Infrastructure                NaN
# 17225     8114622230  Information Technology                NaN
#
#         Position Level                             Generation      Gender  \
# 0                Staff  Generation X (born between 1965-1980)        Male
# ...

# %%
output.to_excel("finaloutput.xlsx", index= False)
